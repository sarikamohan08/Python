# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C://Users//Lenovo//Downloads//IRIS.csv",index_col=0,na_values=["??"])

# %%
data.head()
# Out:
#               sepal_width  petal_length  petal_width      species
# sepal_length
# 5.1                   3.5           1.4          0.2  Iris-setosa
# 4.9                   3.0           1.4          0.2  Iris-setosa
# 4.7                   3.2           1.3          0.2  Iris-setosa
# 4.6                   3.1           1.5          0.2  Iris-setosa
# 5.0                   3.6           1.4          0.2  Iris-setosa

# %%
data=pd.read_csv("C://Users//Lenovo//Downloads//IRIS.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data1=pd.read_excel("C://Users//Lenovo//Downloads//IRIS(excel).xlsx")

# %%
data1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
samp=data.copy(deep=False)#shallow copy
samp
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
samp=data.copy(deep=True)#deep copy
samp
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data2=pd.read_csv("C://Users//Lenovo//Downloads//ToyotaCorolla.csv")

# %%
data2.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3  ?TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ...  Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...             1
# 1         10      2002  72937    Diesel  90          1  ...             1
# 2          9      2002  41711    Diesel  90          1  ...             0
# 3          7      2002  48000    Diesel  90          0  ...             0
# 4          3      2002  38500    Diesel  90          0  ...             1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
data2.index
# Out:
# RangeIndex(start=0, stop=1436, step=1)

# %%
data2.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Automatic', 'cc', 'Doors', 'Cylinders',
#        'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee', 'BOVAG_Guarantee',
#        'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
#        'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
#        'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
#        'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
#        'Tow_Bar'],
#       dtype='object')

# %%
data2.size
# Out:
# 53132

# %%
data2.shape
# Out:
# (1436, 37)

# %%
data2.memory_usage()
# Out:
# Index                 128
# Id                  11488
# Model               11488
# Price               11488
# Age_08_04           11488
# Mfg_Month           11488
# Mfg_Year            11488
# KM                  11488
# Fuel_Type           11488
# HP                  11488
# Met_Color           11488
# Automatic           11488
# cc                  11488
# Doors               11488
# Cylinders           11488
# Gears               11488
# Quarterly_Tax       11488
# Weight              11488
# Mfr_Guarantee       11488
# BOVAG_Guarantee     11488
# Guarantee_Period    11488
# ABS                 11488
# Airbag_1            11488
# Airbag_2            11488
# Airco               11488
# Automatic_airco     11488
# Boardcomputer       11488
# CD_Player           11488
# Central_Lock        11488
# Powered_Windows     11488
# Power_Steering      11488
# Radio               11488
# Mistlamps           11488
# Sport_Model         11488
# Backseat_Divider    11488
# ...

# %%
data2.iat[4,5]
# Out:
# 2002

# %%
data2.dtypes
# Out:
# Id                   int64
# Model               object
# Price                int64
# Age_08_04            int64
# Mfg_Month            int64
# Mfg_Year             int64
# KM                   int64
# Fuel_Type           object
# HP                   int64
# Met_Color            int64
# Automatic            int64
# cc                   int64
# Doors                int64
# Cylinders            int64
# Gears                int64
# Quarterly_Tax        int64
# Weight               int64
# Mfr_Guarantee        int64
# BOVAG_Guarantee      int64
# Guarantee_Period     int64
# ABS                  int64
# Airbag_1             int64
# Airbag_2             int64
# Airco                int64
# Automatic_airco      int64
# Boardcomputer        int64
# CD_Player            int64
# Central_Lock         int64
# Powered_Windows      int64
# Power_Steering       int64
# Radio                int64
# Mistlamps            int64
# Sport_Model          int64
# Backseat_Divider     int64
# ...

# %%
data2.get_dtype_counts() #returns the count off unique data tyoes in the dataframe
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   """Entry point for launching an IPython kernel.
# int64     35
# object     2
# dtype: int64

# %%
data2.select_dtypes(exclude=['object'])
# Out:
#         Id  Price  Age_08_04  Mfg_Month  Mfg_Year     KM   HP  Met_Color  \
# 0        1  13500         23         10      2002  46986   90          1
# 1        2  13750         23         10      2002  72937   90          1
# 2        3  13950         24          9      2002  41711   90          1
# 3        4  14950         26          7      2002  48000   90          0
# 4        5  13750         30          3      2002  38500   90          0
# ...    ...    ...        ...        ...       ...    ...  ...        ...
# 1431  1438   7500         69         12      1998  20544   86          1
# 1432  1439  10845         72          9      1998  19000   86          0
# 1433  1440   8500         71         10      1998  17016   86          0
# 1434  1441   7250         70         11      1998  16916   86          1
# 1435  1442   6950         76          5      1998      1  110          0
#
#       Automatic    cc  ...  Central_Lock  Powered_Windows  Power_Steering  \
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 37 columns):
# Id                  1436 non-null int64
# Model               1436 non-null object
# Price               1436 non-null int64
# Age_08_04           1436 non-null int64
# Mfg_Month           1436 non-null int64
# Mfg_Year            1436 non-null int64
# KM                  1436 non-null int64
# Fuel_Type           1436 non-null object
# HP                  1436 non-null int64
# Met_Color           1436 non-null int64
# Automatic           1436 non-null int64
# cc                  1436 non-null int64
# Doors               1436 non-null int64
# Cylinders           1436 non-null int64
# Gears               1436 non-null int64
# Quarterly_Tax       1436 non-null int64
# Weight              1436 non-null int64
# Mfr_Guarantee       1436 non-null int64
# BOVAG_Guarantee     1436 non-null int64
# Guarantee_Period    1436 non-null int64
# ABS                 1436 non-null int64
# ...

# %%
data2["Met_Color"]=data2["Met_Color"].astype("object")

# %%
data2["Met_Color"].nbytes
# Out:
# 11488

# %%
data2.isna().sum()
# Out:
# Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %%
data2["Fuel_Type"].value_counts()
# Out:
# Petrol    1264
# Diesel     155
# CNG         17
# Name: Fuel_Type, dtype: int64

# %%
data2["Fuel_Type"].value_counts().index[0] #index- above represents
# Out:
# 'Petrol'

# %%
data2["Met_Color"].mode()
# Out:
# 0    1
# dtype: object

# %%
pd.crosstab(index=data2["Fuel_Type"],columns="count",dropna=True)#frequency
# Out:
# col_0      count
# Fuel_Type
# CNG           17
# Diesel       155
# Petrol      1264

# %%
pd.crosstab(index=data2["Automatic"],columns=data2["Fuel_Type"],normalize=True,dropna=True)
#frequency -joint prob
# Out:
# Fuel_Type       CNG    Diesel    Petrol
# Automatic
# 0          0.011142  0.107939  0.825209
# 1          0.000696  0.000000  0.055014

# %%
pd.crosstab(index=data2["Automatic"],columns=data2["Fuel_Type"],normalize=True,margins=True,dropna=True)
#frequency -marginal prob
# Out:
# Fuel_Type       CNG    Diesel    Petrol      All
# Automatic
# 0          0.011142  0.107939  0.825209  0.94429
# 1          0.000696  0.000000  0.055014  0.05571
# All        0.011838  0.107939  0.880223  1.00000

# %%
pd.crosstab(index=data2["Automatic"],columns=data2["Fuel_Type"],normalize='index',margins=True,dropna=True)
#frequency - conditional prob
# Out:
# Fuel_Type       CNG    Diesel    Petrol
# Automatic
# 0          0.011799  0.114307  0.873894
# 1          0.012500  0.000000  0.987500
# All        0.011838  0.107939  0.880223

# %%
pd.crosstab(index=data2["Automatic"],columns=data2["Fuel_Type"],normalize='columns',margins=True,dropna=True)
#frequency - conditional prob
# Out:
# Fuel_Type       CNG  Diesel  Petrol      All
# Automatic
# 0          0.941176     1.0  0.9375  0.94429
# 1          0.058824     0.0  0.0625  0.05571

# %%
numerical_data=data2.select_dtypes(exclude=[object])
numerical_data.shape#correlation all the columns as numbers
# Out:
# (1436, 34)

# %%
corr_matrix=numerical_data.corr()
corr_matrix
# Out:
#                         Id     Price  Age_08_04  Mfg_Month  Mfg_Year  \
# Id                1.000000 -0.738250   0.906132   0.043742 -0.919523
# Price            -0.738250  1.000000  -0.876590  -0.018138  0.885159
# Age_08_04         0.906132 -0.876590   1.000000  -0.123255 -0.983661
# Mfg_Month         0.043742 -0.018138  -0.123255   1.000000 -0.057416
# Mfg_Year         -0.919523  0.885159  -0.983661  -0.057416  1.000000
# KM                0.273298 -0.569960   0.505672  -0.020630 -0.504974
# HP               -0.109375  0.314990  -0.156622  -0.039312  0.164697
# Automatic         0.066265  0.033081   0.031717   0.009146 -0.033567
# cc               -0.117704  0.126389  -0.098084   0.037387  0.091892
# Doors            -0.130207  0.185326  -0.148359  -0.012069  0.151442
# Cylinders              NaN       NaN        NaN        NaN       NaN
# Gears            -0.043343  0.063104  -0.005364  -0.013063  0.007766
# Quarterly_Tax    -0.240821  0.219197  -0.198431   0.031373  0.193934
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.scatter(data2['Age_08_04'],data2["Price"],c="red")
plt.xlabel("age(months)")
plt.ylabel("price(rupee)")
plt.show()

# %%
plt.hist(data2["KM"],color="blue",edgecolor="black",bins=5)
plt.xlabel("kilometer")
plt.ylabel("frequency")
plt.show()

# %%
counts=[979,120,12]
Fuel_Type=["Petrol","Disel","Cng"]
index=np.arange(len(Fuel_Type))

plt.bar(index,counts,color=["Blue","Pink","Violet"])
plt.xlabel("fueltype")
plt.ylabel("frequency")
plt.xticks(index,Fuel_Type,rotation=0)
plt.show()

# %%
sns.set(style="darkgrid")

# %%
sns.regplot(x=data2["Age_08_04"],y=data2["Price"])

# %%
sns.regplot(x=data2["Age_08_04"],y=data2["Price"],fit_reg=False)#by default regressiom is true

# %%
sns.regplot(x=data2["Age_08_04"],y=data2["Price"],marker="*")

# %%
sns.lmplot(x="Age_08_04",y="Price",data=data2,fit_reg=False,hue="Fuel_Type",legend=True)

# %%
sns.distplot(data2["Age_08_04"],kde=False)

# %%
sns.distplot(data2["Age_08_04"],kde=False,bins=5)

# %%
sns.countplot(x="Fuel_Type",data=data2)

# %%
sns.countplot(x="Fuel_Type",data=data2,hue="Automatic")

# %%
sns.boxplot(y="Price",data=data2)

# %%
sns.boxplot(x="Fuel_Type",y="Price",data=data2)#there is no legend for box plot

# %%
sns.boxplot(x="Fuel_Type",y="Price",data=data2,hue="Automatic")

# %%
f,(ax_box,ax_dist)=plt.subplots(2,gridspec_kw={"height_ratios":(.50,.50)})
sns.boxplot(data2["Price"],ax=ax_box)
sns.distplot(data2["Price"],ax=ax_dist,kde=False)

# %%
sns.pairplot(data2,kind="scatter",hue="Fuel_Type")
plt.show()
